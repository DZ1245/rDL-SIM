# %%
from src.utils.read_mrc import read_mrc

# %%
path = '/home/dz/workspace/Biology/rDL-SIM/data_test/rDL-SIM/Biology/MT.mrc'

# %%
header, data = read_mrc(path)

# %%
header
# Out:
# array([(256, 256, 9, 6, 0, 0, 0, 1, 1, 1, 0.0626, 0.0626, 0.16, 90., 90., 90., 1, 2, 3, 0., 0., 0., 0, 0, -16224, b'\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00', 0, 2, b'\x00\x00\x00\x00\x00\x00\x00\x00\x00\x40\x1C\x46\x00\x00\x00\x00\x00\x40\x1C\x46', 0, 1176256512, 0, 0, 196611, 0, 8, [0.e+00, 1.e+04, 1.e-45, 0.e+00, 0.e+00, 0.e+00], 1.0359045e-37, 0., 0., b'', [0, 0, 0, 0], 0., 10, [b'c18-488-0.3W-1.35-2ms', b'c18-488-0.3W-1.35-2ms', b'c18-488-0.3W-1.35-2ms', b'c18-488-0.3W-1.35-2ms', b'c18-488-0.3W-1.35-2ms', b'c18-488-0.3W-1.35-2ms', b'c18-488-0.3W-1.35-2ms', b'c18-488-0.3W-1.35-2ms', b'c18-488-0.3W-1.35-2ms', b'c18-488-0.3W-1.35-2ms'])],
# ...

# %%
data.shape
# Out:
# (256, 256, 9)
